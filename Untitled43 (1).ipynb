# %% [markdown]
# # Processing phase

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures
#importing libraries

# %%
data=pd.read_csv("Downloads/kc_house_data.csv",encoding="ISO-8859-1")
data
#reading the csv file
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
data.info()
#The dataset is loaded in memory
#There is  20 columns in the dataset: 19 numerical features and one categorical feature
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data.head()
#return top 5  rows of a data frame or series
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.shape
##finding number of rows and columns
# Out:
# (21613, 21)

# %%
data.isnull().sum()
#return series containing data about count of NaN in each column.
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# # Visualization phase

# %% [markdown]
# ## Data distribution

# %%
plt.title("house prices by sqft_living")
plt.xlabel('sqft_living')
plt.ylabel('price')
sns.barplot(x='sqft_living',y='price',data=data)
#The house price changes by the existing of a sqf_living
# Out:
# <AxesSubplot:title={'center':'house prices by sqft_living'}, xlabel='sqft_living', ylabel='price'>

# %%
ax=sns.countplot(x="bedrooms",data=data)
#The majority of houses have 3 bedrooms and 4 bedrooms

# %% [markdown]
# ## Data correlation

# %%
X = data.iloc[:,0:20]  #independent columns
y = data.iloc[:,-1]    #target column i.e price range
#get correlations of each features in dataset
correlation_matrix = data.corr()
top_corr_features = correlation_matrix.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="YlGnBu")
#This correlation heatmap contains the correlation coefficients for different variables 
#Each correlation coefficient is colored depending on the value varying from beige for the minimum value -0.4 to the maximum value 1 with dark blue color. Besides the variables correlating with themselves, it is clear that "Sqft_living" and "Sqft_above" are the most correlated variables.

# %% [markdown]
# # Feature Selection

# %% [markdown]
# By observing the kc_house_data, we can notice that the price have correlation with different  features like bedrooms(which is most dependent feature), bathrooms, sqft_living(second most important feature), sqft_lot, floors etc. The price have also a strong dependance with the location of the house where it is present. The other features like waterfront, view are less dependent on the price. Of all the records, there are no missing values, which helps us creating better model.

# %% [markdown]
# # Spliting the data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

# %% [markdown]
# # Applying linear regression to the training dataset

# %%
x=data["sqft_living"].values[:,np.newaxis]
y=data["price"].values
model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
# Out:
# LinearRegression()

# %% [markdown]
# # Ploting the linear regression

# %%
plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x,model.predict(x),color="k")
plt.show()
##red points are the actual outputs
#the black line represents our predicted values
#By observing the graph we can see that there’s a positive correlation between price and sqft_living.

# %% [markdown]
# # Measuring the performance of linear regression using the testing set

# %%
predicted=model.predict(x_test) #testing our models performance
print("MSE", mean_squared_error(y_test,predicted))#MSE
print("R squared", metrics.r2_score(y_test,predicted))#R SQUARED
#MSE=62902408306.86502 it determines the average of the squared prediction error
#R squared =0.4996528488387417 almost equal to 0.5 that's mean :half of the output variation can be explained by the models outputs
# Out:
# MSE 62902408306.86502
# R squared 0.4996528488387417

# %% [markdown]
# # Applying multi-linear regression and compare it to the linear model.

# %%
#extract x and y from our data
x=data[["bedrooms","grade", "sqft_living", "sqft_above"]].values[:, 1:2]  #we have more than one input
y=data["price"].values
model=LinearRegression() #build linear regression model
model.fit(x_train,y_train) #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance
print("MSE", mean_squared_error(y_test,predicted))#MSE
print("R squared", metrics.r2_score(y_test,predicted))#R SQUARED
plt.scatter(x,y,color="r")
plt.title(" Multiple_Linear Regression")
plt.ylabel("price")
plt.xlabel(["bedrooms","grade", "sqft_living", "sqft_above"])
plt.plot(x,model.predict(x),color="k")
plt.show()
#MSE=62902408306.86502 = MSE of linear regression
#R squared=0.4996528488387417= R squared of linear regression
# Out:
# MSE 62902408306.86502
# R squared 0.4996528488387417

# %% [markdown]
# # Applying polynomial regression and compare it to linear and multilinear regression

# %%
#extract x and y from our data
x= data["sqft_living"].values.reshape(-1,1)
y= data["price"].values
lg=LinearRegression()#build linear regression model
poly=PolynomialFeatures(degree=3)#polynomial degree equal to 3
x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)#fitting the training data
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)#testing our models performance
print("MSE: ", metrics.mean_squared_error(y_test, predicted))#MSE
print("R squared: ", metrics.r2_score(y_test,predicted))#R SQUARED
plt.scatter(x, y, color="r")
plt.title("Polynominal_regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x, lg.predict(poly.fit_transform(x)), color="k")
#red points are the actual outputs
#the black line represents our predicted values
#MSE= 58237063981.83721 > MSE of linear regression 
#R squared =0.5367625844600923 > R squared of linear regression 
# Linear and polynomial regression suffer from outliers
# Out:
# MSE:  58237063981.83721
# R squared:  0.5367625844600923
